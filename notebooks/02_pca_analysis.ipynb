# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../data/heart_disease_scaled.csv')

# %%
data.head()
# Out:
#         age  sex  trestbps      chol  fbs   thalach  exang   oldpeak  \
# 0  0.936181  1.0  0.750380 -0.276443  1.0  0.017494    0.0  1.068965
# 1  1.378929  1.0  1.596266  0.744555  0.0 -1.816334    1.0  0.381773
# 2  1.378929  1.0 -0.659431 -0.353500  0.0 -0.899420    1.0  1.326662
# 3 -1.941680  1.0 -0.095506  0.051047  0.0  1.633010    0.0  2.099753
# 4 -1.498933  0.0 -0.095506 -0.835103  0.0  0.978071    0.0  0.295874
#
#          ca  target  cp_2.0  cp_3.0  cp_4.0  restecg_1.0  restecg_2.0  \
# 0 -0.721976       0   False   False   False        False         True
# 1  2.478425       1   False   False    True        False         True
# 2  1.411625       1   False   False    True        False         True
# 3 -0.721976       0   False    True   False        False        False
# 4 -0.721976       0    True   False   False        False         True
#
#    slope_2.0  slope_3.0  thal_6.0  thal_7.0
# 0      False       True      True     False
# ...

# %%
X = data.drop('target',axis=1)
Y = data['target']

# %%
X.head()
# Out:
#         age  sex  trestbps      chol  fbs   thalach  exang   oldpeak  \
# 0  0.936181  1.0  0.750380 -0.276443  1.0  0.017494    0.0  1.068965
# 1  1.378929  1.0  1.596266  0.744555  0.0 -1.816334    1.0  0.381773
# 2  1.378929  1.0 -0.659431 -0.353500  0.0 -0.899420    1.0  1.326662
# 3 -1.941680  1.0 -0.095506  0.051047  0.0  1.633010    0.0  2.099753
# 4 -1.498933  0.0 -0.095506 -0.835103  0.0  0.978071    0.0  0.295874
#
#          ca  cp_2.0  cp_3.0  cp_4.0  restecg_1.0  restecg_2.0  slope_2.0  \
# 0 -0.721976   False   False   False        False         True      False
# 1  2.478425   False   False    True        False         True       True
# 2  1.411625   False   False    True        False         True       True
# 3 -0.721976   False    True   False        False        False      False
# 4 -0.721976    True   False   False        False         True      False
#
#    slope_3.0  thal_6.0  thal_7.0
# 0       True      True     False
# 1      False     False     False
# ...

# %%
Y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    0
# Name: target, dtype: int64

# %%
scalar = StandardScaler()
X_scaled = scalar.fit_transform(X)

# %%
pca = PCA()
X_pca = pca.fit_transform(X)

# %%
plt.figure(figsize=(10, 6))
explained_variance = pca.explained_variance_ratio_.cumsum()
plt.plot(range(1, len(explained_variance) + 1), explained_variance, marker='o', color='green')
plt.title("📉 Cumulative Explained Variance by PCA Components")
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.grid(True)
plt.axhline(y=0.95, color='red', linestyle='--', label='95% threshold')
plt.legend()
plt.show()

# %%
pca = PCA(n_components=10)  
X_reduced = pca.fit_transform(X_scaled)


plt.figure(figsize=(10, 6))
explained_variance = pca.explained_variance_ratio_.cumsum()
plt.plot(range(1, len(explained_variance) + 1), explained_variance, marker='o', color='green')
plt.title("📉 Cumulative Explained Variance by PCA Components")
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.grid(True)
plt.axhline(y=0.95, color='red', linestyle='--', label='95% threshold')
plt.legend()
plt.show()
# Out:
# /home/mohammed/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
